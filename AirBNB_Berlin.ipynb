# %% [markdown]
# # Analyzing Paris AirBnB listings data.
# The following notebook will address some key questions about Berlin AirBnB listings data.

# %% [markdown]
# ## Steps
# 1. **Download Data**
# 2. **Explore Data**
# 3. **Data Cleaning**
# 4. **Analyze/Visualize**
#     1. How are the prices distributed?
#     2. Breakdown of listings by room type.
#     3. What is the median price of a listing by district and room type.
#     4. What is the average difference in a listing price between superhost and non-superhost status for each room type and district?
# 5. **Model**
#     5. Which website options influence the price? (Regression problem: idenfying predictor variables).

# %% [markdown]
# ### Import libraries.

# %%
import os
import wget
import gzip
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import re
import csv
import unidecode
import wptools
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, make_scorer, r2_score

# %matplotlib inline 

#set default style
sns.set_style("whitegrid", {'font.sans-serif': 'DejaVu Sans'})

# %% [markdown]
# ## 1. Download Data
#
# The Berlin data were obtained from Inside AirBnB: http://insideairbnb.com/get-the-data.html. **Download Date**: 17th September 2020. **Sraping Date**: 30th August 2020.
#
# Inside AirBnB serves a map of all the data set samples: http://insideairbnb.com/berlin/

# %%
wget.download("http://data.insideairbnb.com/germany/be/berlin/2020-08-30/data/listings.csv.gz", out=f'{os.getcwd()}\\Data\\AirBNB_Berlin')
wget.download("http://data.insideairbnb.com/germany/be/berlin/2020-08-30/data/calendar.csv.gz",out=f'{os.getcwd()}\\Data\\AirBNB_Berlin')
# Out:
# 'C:\\Users\\ChristianV700\\Documents\\GitHub\\DataScienceProjects\\Data\\AirBNB_Berlin/calendar.csv 1.gz'

# %% [markdown]
# The listings csv contains all active accommodations for Berlin.

# %%
import gzip

with gzip.open('Data/AirBNB_Berlin/listings.csv.gz') as f:
    listings = pd.read_csv(f)

listings.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  1944  https://www.airbnb.com/rooms/1944  20200830153825   2020-08-31
# 1  3176  https://www.airbnb.com/rooms/3176  20200830153825   2020-08-31
# 2  3309  https://www.airbnb.com/rooms/3309  20200830153825   2020-09-01
# 3  7071  https://www.airbnb.com/rooms/7071  20200830153825   2020-08-31
# 4  9991  https://www.airbnb.com/rooms/9991  20200830153825   2020-08-31
#
#                                   name  \
# 0               cafeheaven Pberg/Mitte
# 1      Fabulous Flat in great Location
# 2    BerlinSpot Schöneberg near KaDeWe
# 3     BrightRoom with sunny greenview!
# 4  Geourgeous flat - outstanding views
#
#                                          description  \
# 0  Private, bright and friendly room. You'd be sh...
# 1  This beautiful first floor apartment  is situa...
# 2  First of all:<br />I prefer short-notice booki...
# 3  Cozy and large room in the beautiful district ...
# 4  4 bedroom with very large windows and outstand...
#
#                                neighborhood_overview  \
# 0  near all the trendy cafés and flea markets and...
# 1  The neighbourhood is famous for its variety of...
# 2  My flat is in the middle of West-Berlin, direc...
# 3  Great neighborhood with plenty of Cafés, Baker...
# 4  Prenzlauer Berg is an amazing neighbourhood wh...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/107924758/1f4...     2164
# 1  https://a0.muscache.com/pictures/243355/84afcf...     3718
# 2  https://a0.muscache.com/pictures/29054294/b1fa...     4108
# 3  https://a0.muscache.com/pictures/21278/32a1622...    17391
# 4  https://a0.muscache.com/pictures/42799131/59c8...    33852
#
#                                   host_url  ... review_scores_communication  \
# 0   https://www.airbnb.com/users/show/2164  ...                         9.0
# 1   https://www.airbnb.com/users/show/3718  ...                         9.0
# 2   https://www.airbnb.com/users/show/4108  ...                        10.0
# 3  https://www.airbnb.com/users/show/17391  ...                        10.0
# 4  https://www.airbnb.com/users/show/33852  ...                        10.0
#
#   review_scores_location review_scores_value            license  \
# 0                    9.0                 8.0                NaN
# 1                   10.0                 9.0                NaN
# 2                    9.0                 9.0                NaN
# 3                   10.0                 9.0                NaN
# 4                   10.0                10.0  03/Z/RA/003410-18
#
#   instant_bookable calculated_host_listings_count  \
# 0                f                              2
# 1                f                              1
# 2                f                              1
# 3                t                              1
# 4                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           1
# 2                                           0
# 3                                           0
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            2
# 1                                            0
# 2                                            1
# 3                                            1
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.21
# 1                                           0              1.07
# 2                                           0              0.31
# 3                                           0              2.18
# 4                                           0              0.13
#
# [5 rows x 74 columns]

# %% [markdown]
# The calendar csv contains all the posted dates and prices listed for each location.

# %%
with gzip.open('Data/AirBNB_Berlin/calendar.csv.gz') as f:
    calendar = pd.read_csv(f)

calendar.head()
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0      186851  2020-09-01         f  $33.00         $33.00            62.0
# 1        1944  2020-08-31         f  $20.00         $20.00            60.0
# 2        1944  2020-09-01         f  $20.00         $20.00            60.0
# 3        1944  2020-09-02         f  $20.00         $20.00            60.0
# 4        1944  2020-09-03         f  $20.00         $20.00            60.0
#
#    maximum_nights
# 0           300.0
# 1           120.0
# 2           120.0
# 3           120.0
# 4           120.0

# %% [markdown]
# ## 2. Explore Data

# %%
#get general info
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20432 entries, 0 to 20431
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            20432 non-null  int64
#  1   listing_url                                   20432 non-null  object
#  2   scrape_id                                     20432 non-null  int64
#  3   last_scraped                                  20432 non-null  object
#  4   name                                          20400 non-null  object
#  5   description                                   19918 non-null  object
#  6   neighborhood_overview                         11186 non-null  object
#  7   picture_url                                   20432 non-null  object
#  8   host_id                                       20432 non-null  int64
#  9   host_url                                      20432 non-null  object
#  10  host_name                                     20420 non-null  object
#  11  host_since                                    20420 non-null  object
#  12  host_location                                 20368 non-null  object
#  13  host_about                                    10396 non-null  object
#  14  host_response_time                            10132 non-null  object
#  15  host_response_rate                            10132 non-null  object
#  16  host_acceptance_rate                          13617 non-null  object
#  17  host_is_superhost                             20420 non-null  object
#  18  host_thumbnail_url                            20420 non-null  object
#  19  host_picture_url                              20420 non-null  object
#  20  host_neighbourhood                            14900 non-null  object
#  21  host_listings_count                           20420 non-null  float64
#  22  host_total_listings_count                     20420 non-null  float64
#  23  host_verifications                            20432 non-null  object
#  24  host_has_profile_pic                          20420 non-null  object
#  25  host_identity_verified                        20420 non-null  object
#  26  neighbourhood                                 11187 non-null  object
#  27  neighbourhood_cleansed                        20432 non-null  object
#  28  neighbourhood_group_cleansed                  20432 non-null  object
#  29  latitude                                      20432 non-null  float64
#  30  longitude                                     20432 non-null  float64
#  31  property_type                                 20432 non-null  object
#  32  room_type                                     20432 non-null  object
#  33  accommodates                                  20432 non-null  int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                20409 non-null  object
#  36  bedrooms                                      18742 non-null  float64
#  37  beds                                          20196 non-null  float64
#  38  amenities                                     20432 non-null  object
#  39  price                                         20432 non-null  object
#  40  minimum_nights                                20432 non-null  int64
#  41  maximum_nights                                20432 non-null  int64
#  42  minimum_minimum_nights                        20431 non-null  float64
#  43  maximum_minimum_nights                        20431 non-null  float64
#  44  minimum_maximum_nights                        20431 non-null  float64
#  45  maximum_maximum_nights                        20431 non-null  float64
#  46  minimum_nights_avg_ntm                        20431 non-null  float64
#  47  maximum_nights_avg_ntm                        20431 non-null  float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              20432 non-null  object
#  50  availability_30                               20432 non-null  int64
#  51  availability_60                               20432 non-null  int64
#  52  availability_90                               20432 non-null  int64
#  53  availability_365                              20432 non-null  int64
#  54  calendar_last_scraped                         20432 non-null  object
#  55  number_of_reviews                             20432 non-null  int64
#  56  number_of_reviews_ltm                         20432 non-null  int64
#  57  number_of_reviews_l30d                        20432 non-null  int64
#  58  first_review                                  16574 non-null  object
#  59  last_review                                   16574 non-null  object
#  60  review_scores_rating                          16153 non-null  float64
#  61  review_scores_accuracy                        16133 non-null  float64
#  62  review_scores_cleanliness                     16134 non-null  float64
#  63  review_scores_checkin                         16120 non-null  float64
#  64  review_scores_communication                   16131 non-null  float64
#  65  review_scores_location                        16122 non-null  float64
#  66  review_scores_value                           16119 non-null  float64
#  67  license                                       2399 non-null   object
#  68  instant_bookable                              20432 non-null  object
#  69  calculated_host_listings_count                20432 non-null  int64
#  70  calculated_host_listings_count_entire_homes   20432 non-null  int64
#  71  calculated_host_listings_count_private_rooms  20432 non-null  int64
#  72  calculated_host_listings_count_shared_rooms   20432 non-null  int64
#  73  reviews_per_month                             16574 non-null  float64
# dtypes: float64(22), int64(17), object(35)
# memory usage: 11.5+ MB

# %%
#see how many room types
listings.room_type.value_counts()
# Out:
# Entire home/apt    11047
# Private room        8870
# Shared room          279
# Hotel room           236
# Name: room_type, dtype: int64

# %%
#check for any missing values
listings.room_type.isna().sum()
# Out:
# 0

# %%
#see the accomodates numbers
listings.accommodates.value_counts()
# Out:
# 2     10739
# 4      3055
# 1      2350
# 3      2243
# 6       806
# 5       710
# 8       168
# 7       150
# 10       66
# 9        44
# 12       33
# 16       22
# 11       17
# 14       13
# 15        7
# 13        7
# 0         2
# Name: accommodates, dtype: int64

# %%
#check for any missing values
listings.accommodates.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Bathrooms

# %%
#see bathroom count. Somewhat little consistency. Note that all of the non-numeric values are half baths (toilet only, no shower)!
listings.bathrooms_text.value_counts()
# Out:
# 1 bath               11275
# 1 shared bath         5340
# 1 private bath         895
# 2 baths                866
# 1.5 baths              821
# 1.5 shared baths       533
# 2 shared baths         289
# 2.5 baths              111
# 2.5 shared baths        50
# 0 baths                 45
# 3 baths                 44
# Half-bath               40
# 0 shared baths          29
# Shared half-bath        18
# 4 baths                 10
# 7 baths                  9
# 3 shared baths           8
# 3.5 baths                6
# 4 shared baths           4
# 5 shared baths           4
# 4.5 baths                3
# 8.5 shared baths         3
# Private half-bath        2
# 8 baths                  1
# 5 baths                  1
# 7.5 baths                1
# 6 baths                  1
# Name: bathrooms_text, dtype: int64

# %%
#check for any missing values
listings.bathrooms_text.isna().sum()

#23 locations are missing bathrooms?
# Out:
# 23

# %%
#Explore listings with missing bathroom value 
listings[listings.bathrooms_text.isna()][['bathrooms_text','beds', 'bedrooms', 'listing_url', 'property_type']].head(10)
# Out:
#     bathrooms_text  beds  bedrooms                          listing_url  \
# 35             NaN   2.0       2.0   https://www.airbnb.com/rooms/52570
# 88             NaN   1.0       1.0  https://www.airbnb.com/rooms/162111
# 118            NaN   1.0       1.0  https://www.airbnb.com/rooms/186717
# 123            NaN   1.0       1.0  https://www.airbnb.com/rooms/189596
# 192            NaN   2.0       1.0  https://www.airbnb.com/rooms/246007
# 218            NaN   3.0       1.0  https://www.airbnb.com/rooms/254551
# 271            NaN   1.0       1.0  https://www.airbnb.com/rooms/302167
# 388            NaN   1.0       1.0  https://www.airbnb.com/rooms/512476
# 412            NaN   3.0       1.0  https://www.airbnb.com/rooms/555352
# 416            NaN   1.0       1.0  https://www.airbnb.com/rooms/563505
#
#                  property_type
# 35            Entire apartment
# 88   Private room in apartment
# 118           Entire apartment
# 123           Entire apartment
# 192           Entire apartment
# 218           Entire apartment
# 271           Entire apartment
# 388           Entire apartment
# 412                  Camper/RV
# 416           Entire apartment

# %%
#What kind of properties explicitly contain zero bathroom?
listings.loc[listings['bathrooms_text']=='0 baths'][['bathrooms_text','beds', 'bedrooms', 'listing_url', 'property_type']]
# Out:
#       bathrooms_text  beds  bedrooms                            listing_url  \
# 219          0 baths   3.0       1.0    https://www.airbnb.com/rooms/254559
# 226          0 baths   3.0       NaN    https://www.airbnb.com/rooms/255209
# 242          0 baths   1.0       1.0    https://www.airbnb.com/rooms/265389
# 531          0 baths   2.0       1.0    https://www.airbnb.com/rooms/726236
# 681          0 baths   1.0       1.0    https://www.airbnb.com/rooms/926497
# 1208         0 baths   0.0       NaN   https://www.airbnb.com/rooms/2070349
# 1950         0 baths   1.0       NaN   https://www.airbnb.com/rooms/4018296
# 2299         0 baths   1.0       NaN   https://www.airbnb.com/rooms/4816644
# 2659         0 baths   1.0       1.0   https://www.airbnb.com/rooms/5875924
# 2826         0 baths   1.0       1.0   https://www.airbnb.com/rooms/6322584
# 4188         0 baths   1.0       1.0   https://www.airbnb.com/rooms/9400886
# 4536         0 baths   1.0       NaN  https://www.airbnb.com/rooms/10067529
# 6241         0 baths   1.0       1.0  https://www.airbnb.com/rooms/14588522
# 6830         0 baths   1.0       1.0  https://www.airbnb.com/rooms/16228910
# 10960        0 baths   1.0       NaN  https://www.airbnb.com/rooms/24057633
# 12916        0 baths   0.0       NaN  https://www.airbnb.com/rooms/29649426
# 13273        0 baths   0.0       NaN  https://www.airbnb.com/rooms/30548092
# 13647        0 baths   1.0       1.0  https://www.airbnb.com/rooms/31452001
# 13716        0 baths   1.0       1.0  https://www.airbnb.com/rooms/31646871
# 13916        0 baths   1.0       1.0  https://www.airbnb.com/rooms/32241292
# 14266        0 baths   1.0       NaN  https://www.airbnb.com/rooms/33067984
# 14433        0 baths   1.0       2.0  https://www.airbnb.com/rooms/33567229
# 14971        0 baths   1.0       1.0  https://www.airbnb.com/rooms/35145878
# 14976        0 baths   3.0       1.0  https://www.airbnb.com/rooms/35151612
# 14978        0 baths   2.0       1.0  https://www.airbnb.com/rooms/35151676
# 14980        0 baths   1.0       1.0  https://www.airbnb.com/rooms/35152299
# 14982        0 baths   1.0       1.0  https://www.airbnb.com/rooms/35153427
# 15130        0 baths   0.0       NaN  https://www.airbnb.com/rooms/35535160
# 15163        0 baths   1.0       2.0  https://www.airbnb.com/rooms/35620288
# 15484        0 baths   2.0       1.0  https://www.airbnb.com/rooms/36328793
# 15485        0 baths   1.0       1.0  https://www.airbnb.com/rooms/36330117
# 15489        0 baths   2.0       1.0  https://www.airbnb.com/rooms/36331449
# 15597        0 baths   3.0       1.0  https://www.airbnb.com/rooms/36541436
# 16386        0 baths   1.0       NaN  https://www.airbnb.com/rooms/38469027
# 16534        0 baths   NaN       NaN  https://www.airbnb.com/rooms/38802547
# 16542        0 baths   NaN       NaN  https://www.airbnb.com/rooms/38813440
# 16903        0 baths   NaN       NaN  https://www.airbnb.com/rooms/39527464
# 17153        0 baths   1.0       1.0  https://www.airbnb.com/rooms/39980622
# 17926        0 baths   NaN       NaN  https://www.airbnb.com/rooms/41173528
# 18127        0 baths   NaN       1.0  https://www.airbnb.com/rooms/41588395
# 19090        0 baths   1.0       NaN  https://www.airbnb.com/rooms/43055810
# 19220        0 baths   1.0       1.0  https://www.airbnb.com/rooms/43441318
# 19260        0 baths   3.0       1.0  https://www.airbnb.com/rooms/43511150
# 19815        0 baths   1.0       NaN  https://www.airbnb.com/rooms/44245844
# 19899        0 baths   2.0       1.0  https://www.airbnb.com/rooms/44325496
#
#                    property_type
# 219             Entire apartment
# 226             Entire apartment
# 242       Private room in hostel
# 531             Entire apartment
# 681    Private room in apartment
# 1208            Entire apartment
# 1950                 Entire loft
# 2299            Entire apartment
# 2659   Private room in apartment
# 2826   Private room in apartment
# 4188            Entire apartment
# 4536                 Entire loft
# 6241            Entire apartment
# 6830            Entire apartment
# 10960           Entire apartment
# 12916           Entire apartment
# 13273           Entire apartment
# 13647           Entire apartment
# 13716           Entire apartment
# 13916           Entire apartment
# 14266                  Camper/RV
# 14433           Entire apartment
# 14971     Room in boutique hotel
# 14976     Room in boutique hotel
# 14978     Room in boutique hotel
# 14980     Room in boutique hotel
# 14982     Room in boutique hotel
# 15130               Entire house
# 15163           Entire apartment
# 15484             Room in hostel
# 15485             Room in hostel
# 15489             Room in hostel
# 15597                       Boat
# 16386           Entire apartment
# 16534  Private room in apartment
# 16542  Private room in apartment
# 16903  Private room in apartment
# 17153  Private room in apartment
# 17926           Entire apartment
# 18127  Private room in apartment
# 19090                Entire loft
# 19220  Private room in apartment
# 19260                       Boat
# 19815           Entire apartment
# 19899              Room in hotel

# %% [markdown]
# ## Bedrooms/Beds

# %%
#see bedroom count - There are no samples with explicitly 0 bedrooms!
listings.bedrooms.value_counts()
# Out:
# 1.0     14997
# 2.0      2823
# 3.0       709
# 4.0       150
# 5.0        37
# 6.0        16
# 7.0         4
# 8.0         3
# 10.0        2
# 12.0        1
# Name: bedrooms, dtype: int64

# %%
#but there are plenty of missing values
listings.bedrooms.isna().sum()
# Out:
# 1690

# %%
#see bed counts - There are no samples with explicitly 0 beds!
listings.beds.value_counts()
# Out:
# 1.0     11849
# 2.0      4820
# 3.0      1380
# 4.0       758
# 0.0       690
# 5.0       277
# 6.0       224
# 7.0        78
# 8.0        54
# 10.0       22
# 9.0        17
# 12.0        8
# 11.0        7
# 16.0        5
# 15.0        3
# 14.0        2
# 17.0        2
# Name: beds, dtype: int64

# %%
#check for any missing values
listings.beds.isna().sum()

#236 that do not have any information about beds
#might be interesting to look into these to see if this is just an error or if there are actually no beds...
# Out:
# 236

# %%
#exlpore entries with missing bed value
# if they have a bedroom listed then they surely have a bed... what about the entries with missing bed and missing bedroom value?

listings[listings.beds.isna() &listings.bedrooms.isna() ][['beds','room_type','listing_url', 'bedrooms']]
# Out:
#        beds        room_type                            listing_url  bedrooms
# 6685    NaN  Entire home/apt  https://www.airbnb.com/rooms/15933853       NaN
# 12320   NaN  Entire home/apt  https://www.airbnb.com/rooms/28132083       NaN
# 16534   NaN     Private room  https://www.airbnb.com/rooms/38802547       NaN
# 16542   NaN     Private room  https://www.airbnb.com/rooms/38813440       NaN
# 16903   NaN     Private room  https://www.airbnb.com/rooms/39527464       NaN
# 17069   NaN  Entire home/apt  https://www.airbnb.com/rooms/39839444       NaN
# 17339   NaN  Entire home/apt  https://www.airbnb.com/rooms/40335581       NaN
# 17474   NaN  Entire home/apt  https://www.airbnb.com/rooms/40546946       NaN
# 17487   NaN  Entire home/apt  https://www.airbnb.com/rooms/40563469       NaN
# 17848   NaN     Private room  https://www.airbnb.com/rooms/41044666       NaN
# 17926   NaN  Entire home/apt  https://www.airbnb.com/rooms/41173528       NaN
# 18507   NaN  Entire home/apt  https://www.airbnb.com/rooms/42247016       NaN
# 18514   NaN  Entire home/apt  https://www.airbnb.com/rooms/42261622       NaN
# 18518   NaN     Private room  https://www.airbnb.com/rooms/42264353       NaN
# 18541   NaN       Hotel room  https://www.airbnb.com/rooms/42279207       NaN
# 18845   NaN       Hotel room  https://www.airbnb.com/rooms/42687506       NaN
# 19296   NaN  Entire home/apt  https://www.airbnb.com/rooms/43552277       NaN
# 19560   NaN       Hotel room  https://www.airbnb.com/rooms/43934655       NaN
# 19809   NaN  Entire home/apt  https://www.airbnb.com/rooms/44242036       NaN
# 20089   NaN     Private room  https://www.airbnb.com/rooms/44544771       NaN
# 20244   NaN  Entire home/apt  https://www.airbnb.com/rooms/44775716       NaN

# %% [markdown]
# ## Minimum Nights

# %%
#check for missing values
listings.minimum_nights.isna().sum()
# Out:
# 0

# %%
#see property type count
listings.property_type.value_counts()
#there are some interesting listing types!
# Out:
# Entire apartment             9652
# Private room in apartment    7951
# Entire loft                   358
# Entire condominium            305
# Entire serviced apartment     302
#                              ...
# Private room in tipi            1
# Private room in cave            1
# Shared room in tiny house       1
# Castle                          1
# Shared room in dome house       1
# Name: property_type, Length: 66, dtype: int64

# %%
#check for any missing values 
listings.property_type.isna().sum()
# Out:
# 0

# %%
#how many unique listings at the time of scraping?
listings.id.nunique()
# Out:
# 20432

# %%
#explore neighbourhoods_cleansed
listings.neighbourhood_cleansed.value_counts()
# Out:
# Frankfurter Allee Süd FK              1159
# Alexanderplatz                        1117
# Tempelhofer Vorstadt                  1027
# Reuterstraße                           847
# Brunnenstr. Süd                        779
#                                       ...
# Allende-Viertel                          3
# Neu-Hohenschönhausen Süd                 3
# Neu-Hohenschönhausen Nord                2
# Malchow, Wartenberg und Falkenberg       2
# Marzahn-Nord                             1
# Name: neighbourhood_cleansed, Length: 137, dtype: int64

# %% [markdown]
# ## 3. Data Cleaning
#
# A. Perform some tidying on the listings df - to be used for data visualization.
#  1. Remove some random columns that will not be used in this analysis and remove columns with All NAs.
#  2. Create district column using the cleansed neighbourhoods
#      -> Use the wptools API to get the neighbourhoods by districts table on the Wiki Page.
#  3. Clean up odd bedroom numbers and infer any missing.
#  4. Clean up odd bathrooms and infer any missing.
#  5. Infer missing beds.
#  6. Clean up price.
#
# B. Join the calendar df with the listings df to get the price of each listing at a certain date.
#     Note***: Will still retain the original listings df for data visualization purposes.
#  1. Remove some columns not interested in
#  2. Create day of the week using the date in cal df.
#  3. Select only unique days (Monday - Friday for each listing_id x month X year)
#  4. Clean up adjusted price.

# %% [markdown]
# ### A. Perform some tidying of the listings df.
#
# ### Fix 'Bedrooms'

# %%
#remove columns that have all missing values 
listings.columns[listings.isnull().mean()==1].tolist()
# Out:
# ['bathrooms', 'calendar_updated']

# %%
#remove columns that have all missing values 
listings = listings.drop(listings.columns[listings.isnull().mean()==1].tolist(), axis=1)

# %%
#fill in the bedrooms using information from other columns -> 'name' and 'description' indicate that NaN in 'bedrooms' is often the case studio apartments
listings[listings.bedrooms.isna()][['bedrooms','beds','name', 'description', 'room_type']]
# Out:
#        bedrooms  beds                                              name  \
# 5           NaN   1.0                      Apartment in Prenzlauer Berg
# 7           NaN   0.0              Beautiful Kreuzberg studio/fast WiFi
# 16          NaN   1.0            Beautiful apartment in Prenzlauer Berg
# 47          NaN   2.0    Quiet studio in Prenzlauer Berg near Mauerpark
# 79          NaN   1.0               1-room apartment in Kreuzkölln/WIFI
# ...         ...   ...                                               ...
# 20402       NaN   4.0   In der Nähe der U-Bahnstation finden 7 Personen
# 20409       NaN   1.0      Cozy Quiet Apartment in the center of Berlin
# 20421       NaN   0.0    Sunny duplex apt. on northern Friedrichstrasse
# 20423       NaN   1.0   Apartment near Alexanderplatz in Friedrichshain
# 20429       NaN   0.0  Am Alexanderplatz mit Blick auf den Fernsehturm!
#
#                                              description        room_type
# 5      The apartment is located on the upper second f...  Entire home/apt
# 7      - beautiful studio apt in downtown Berlin - cl...  Entire home/apt
# 16     The apartment is located on the upper ground f...  Entire home/apt
# 47     COVID CLEANING PROTOCOL<br />In order to help ...  Entire home/apt
# 79     Best location on the canal/Kottbusser Damm. Th...  Entire home/apt
# ...                                                  ...              ...
# 20402  Das Apartment verfügt über einen Essbereich, e...  Entire home/apt
# 20409  My apartment is super central yet super quiet....  Entire home/apt
# 20421  Very comfortable 60 square meters duplex apart...  Entire home/apt
# 20423  Genieße Deinen nächsten Berlin-Aufenthalt in u...  Entire home/apt
# 20429  Schöne Wohnung. Direkt am Alexanderplatz, Blic...  Entire home/apt
#
# [1690 rows x 5 columns]

# %% [markdown]
# ### Studios are a tough decision what to fill in. Zero or One? Many hosts simply leave it blank when listing.
# I will call a studio a 0-bedroom location to have it as a separate category distinguishable from larger apartments.

# %%
#assign 0 bedrooms to NAN
listings['bedrooms'] = np.where(listings['bedrooms'].isna(), 0, listings['bedrooms'])
#check to make sure it worked
listings.bedrooms.isna().sum()
# Out:
# 0

# %% [markdown]
# The 'Accommodates' feature can be used to fill in 'Beds' where missing.

# %%
#now look at beds
listings[listings.beds.isna()][['beds','description', 'listing_url', 'bathrooms_text', 'bedrooms', 'accommodates']].head(20)
# Out:
#        beds                                        description  \
# 449     NaN  <b>The space</b><br />Very nice 4-room apartme...
# 507     NaN  <b>The space</b><br />Wohnart: Wohnung  <br />...
# 1034    NaN               <b>The space</b><br />schöne wohnung
# 1544    NaN  A quiet location in the heart of Friedrichshai...
# 6685    NaN  Meine Unterkunft ist in der Nähe von Neukölln ...
# 6784    NaN  I'm renting my cousy room in shared apartment,...
# 9072    NaN  Zentral und ruhig gelegen im beliebten Kiez Ne...
# 9105    NaN  I'm subletting my lovely room in the Berlin di...
# 9113    NaN  Big, bright and airy room in a comfortable and...
# 11927   NaN  <b>The space</b><br />We are a family owned an...
# 11928   NaN  <b>The space</b><br />We are a family owned an...
# 12320   NaN                                                NaN
# 12536   NaN  <b>The space</b><br />Colorful room with woode...
# 12537   NaN  <b>The space</b><br />Colorful room with woode...
# 12538   NaN  <b>The space</b><br />Colorful room with woode...
# 12539   NaN  <b>The space</b><br />Colorful room with woode...
# 12540   NaN  <b>The space</b><br />Colorful room with woode...
# 12541   NaN  <b>The space</b><br />Comfort sleep tower on 3...
# 12645   NaN  <b>The space</b><br />An old gem is polished. ...
# 12646   NaN  <b>The space</b><br />An old gem is polished. ...
#
#                                  listing_url  bathrooms_text  bedrooms  \
# 449      https://www.airbnb.com/rooms/609459             NaN       1.0
# 507      https://www.airbnb.com/rooms/694373             NaN       1.0
# 1034    https://www.airbnb.com/rooms/1660112             NaN       1.0
# 1544    https://www.airbnb.com/rooms/3023254             NaN       1.0
# 6685   https://www.airbnb.com/rooms/15933853          1 bath       0.0
# 6784   https://www.airbnb.com/rooms/16144309       1.5 baths       1.0
# 9072   https://www.airbnb.com/rooms/20522634          1 bath       1.0
# 9105   https://www.airbnb.com/rooms/20589409   1 shared bath       1.0
# 9113   https://www.airbnb.com/rooms/20598100   1 shared bath       1.0
# 11927  https://www.airbnb.com/rooms/27011856  1 private bath       1.0
# 11928  https://www.airbnb.com/rooms/27011860  1 private bath       1.0
# 12320  https://www.airbnb.com/rooms/28132083             NaN       0.0
# 12536  https://www.airbnb.com/rooms/28599090          1 bath       1.0
# 12537  https://www.airbnb.com/rooms/28599092          1 bath       1.0
# 12538  https://www.airbnb.com/rooms/28599093          1 bath       1.0
# 12539  https://www.airbnb.com/rooms/28599096          1 bath       1.0
# 12540  https://www.airbnb.com/rooms/28599111          1 bath       1.0
# 12541  https://www.airbnb.com/rooms/28599112          1 bath       1.0
# 12645  https://www.airbnb.com/rooms/28879428          1 bath       1.0
# 12646  https://www.airbnb.com/rooms/28879430          1 bath       1.0
#
#        accommodates
# 449               2
# 507               2
# 1034              1
# 1544              2
# 6685              1
# 6784              2
# 9072              2
# 9105              2
# 9113              2
# 11927             2
# 11928             2
# 12320             3
# 12536             2
# 12537             1
# 12538             1
# 12539             2
# 12540             4
# 12541             2
# 12645             2
# 12646             2

# %%
listings[listings.beds.isna()][['description', 'listing_url', 'bathrooms_text', 'bedrooms', 'accommodates']].accommodates.value_counts()
# Out:
# 2    144
# 1     58
# 6     16
# 4     11
# 3      5
# 0      2
# Name: accommodates, dtype: int64

# %% [markdown]
# ### Fix beds

# %%
#if listing accomodates 1 there must be only 1 bed
listings.loc[(listings['accommodates'] == 1), 'beds'] = 1

#if there is 1 bedroom and accomodates 2 there must be at least 1 double bed
listings.loc[((listings['accommodates'] == 2) & (listings['bedrooms'] == 1)) , 'beds'] = 1

#if there are 2 bedrooms and accomodates 4 there must be at least 2 beds -> two double beds
listings.loc[((listings['accommodates'] == 4) & (listings['bedrooms'] == 2)) , 'beds'] = 2

#if there are 3 bedrooms and accomodates 5 there must be at least 3 beds
accom = [5,6]
listings.loc[((listings['accommodates'].isin(accom)) & (listings['bedrooms'] == 3)) , 'beds'] = 3

# %%
# after that tidying up, how many samples are sill left with NA?
listings.beds.isna().sum()
# Out:
# 47

# %%
#assign 1 bed to these ones missing 
listings['beds'] = np.where(listings['beds'].isna(), 1, listings['beds'])
#check to make sure it worked
listings.beds.isna().sum()
# Out:
# 0

# %% [markdown]
# ### Fix 'Bathrooms'

# %%
listings[['beds','description', 'listing_url', 'bathrooms_text', 'bedrooms', 'accommodates']].head(40)
# Out:
#     beds                                        description  \
# 0    1.0  Private, bright and friendly room. You'd be sh...
# 1    2.0  This beautiful first floor apartment  is situa...
# 2    1.0  First of all:<br />I prefer short-notice booki...
# 3    1.0  Cozy and large room in the beautiful district ...
# 4    7.0  4 bedroom with very large windows and outstand...
# 5    1.0  The apartment is located on the upper second f...
# 6    3.0  Light and sunny 2-Room-turn of the century-fla...
# 7    0.0  - beautiful studio apt in downtown Berlin - cl...
# 8    2.0  Bright and sunny condo with two balconies in a...
# 9    2.0  Light and sunny 1-Room-turn of the century-fla...
# 10   2.0  <b>The space</b><br />Very nice furnished 2 be...
# 11   4.0  Free Internet and phone included.<br /><br />A...
# 12   4.0  Comfortable, cozy and quiet 70m2 apartment plu...
# 13   3.0  Beautiful and calm apartment in close vicinity...
# 14   2.0  <b>The space</b><br />The apartment has 150 sq...
# 15   2.0  <b>The space</b><br />The apartment has 150 sq...
# 16   1.0  The apartment is located on the upper ground f...
# 17   2.0  This charming apartment located in a building ...
# 18   4.0  Right in the heart of Prenzlauer Berg, probabl...
# 19   1.0  nice room to rent, not longer then 2 weeks or ...
# 20   2.0  Welcome in our nice apartment: airy bedroom, g...
# 21   1.0  You are looking at a wonderful private room wi...
# 22   1.0  A good place to stay in the city, clean, well-...
# 23   1.0  Central, quiet, bright and ample in a beautifu...
# 24   1.0  <b>The space</b><br />Beautiful 20 sq.m. room ...
# 25   1.0  Looking for a new tenant starting at the begin...
# 26   1.0  Our spacious and bright 2-room apartment will ...
# 27   1.0  <b>The space</b><br />We enjoy having guests a...
# 28   1.0  Nice and big room with a balcony, wooden floor...
# 29   1.0  Schönes Altbauzimmer für einieg Tage zu Vermie...
# 30   1.0  <b>The space</b><br />Spacious 35 square metre...
# 31   2.0  A large art filled two bedroom holiday apartme...
# 32   1.0  Because of the current situation, I only suble...
# 33   1.0  The flat is located in the middle of the vibra...
# 34   3.0  We are subletting our beautiful 150 sqm apartm...
# 35   2.0  <b>The space</b><br />Nicely furnished apartme...
# 36   1.0  You won't find a more centrally located place ...
# 37   1.0  <b>The space</b><br />On the most famous antiq...
# 38   2.0  An apartment of 130 sqm right in the heart of ...
# 39   4.0  This apartment is a LEGAL holiday flat (01/Z/Z...
#
#                            listing_url    bathrooms_text  bedrooms  \
# 0    https://www.airbnb.com/rooms/1944     1 shared bath       1.0
# 1    https://www.airbnb.com/rooms/3176            1 bath       1.0
# 2    https://www.airbnb.com/rooms/3309     1 shared bath       1.0
# 3    https://www.airbnb.com/rooms/7071     1 shared bath       1.0
# 4    https://www.airbnb.com/rooms/9991         2.5 baths       4.0
# 5   https://www.airbnb.com/rooms/14325            1 bath       0.0
# 6   https://www.airbnb.com/rooms/16644            1 bath       1.0
# 7   https://www.airbnb.com/rooms/17904            1 bath       0.0
# 8   https://www.airbnb.com/rooms/20858            1 bath       2.0
# 9   https://www.airbnb.com/rooms/21869            1 bath       1.0
# 10  https://www.airbnb.com/rooms/22415            1 bath       2.0
# 11  https://www.airbnb.com/rooms/22438            1 bath       2.0
# 12  https://www.airbnb.com/rooms/22677            1 bath       1.0
# 13  https://www.airbnb.com/rooms/23834            1 bath       1.0
# 14  https://www.airbnb.com/rooms/24569         2.5 baths       2.0
# 15  https://www.airbnb.com/rooms/25653         2.5 baths       2.0
# 16  https://www.airbnb.com/rooms/28156            1 bath       0.0
# 17  https://www.airbnb.com/rooms/29279            1 bath       2.0
# 18  https://www.airbnb.com/rooms/30295            1 bath       2.0
# 19  https://www.airbnb.com/rooms/31440     1 shared bath       1.0
# 20  https://www.airbnb.com/rooms/33043            1 bath       1.0
# 21  https://www.airbnb.com/rooms/35152    1 private bath       1.0
# 22  https://www.airbnb.com/rooms/36480    0 shared baths       1.0
# 23  https://www.airbnb.com/rooms/37052            1 bath       1.0
# 24  https://www.airbnb.com/rooms/37836  1.5 shared baths       1.0
# 25  https://www.airbnb.com/rooms/38074            1 bath       1.0
# 26  https://www.airbnb.com/rooms/38296            1 bath       1.0
# 27  https://www.airbnb.com/rooms/40600            1 bath       1.0
# 28  https://www.airbnb.com/rooms/41217     1 shared bath       1.0
# 29  https://www.airbnb.com/rooms/41306            1 bath       1.0
# 30  https://www.airbnb.com/rooms/42742  1.5 shared baths       1.0
# 31  https://www.airbnb.com/rooms/42809            1 bath       2.0
# 32  https://www.airbnb.com/rooms/44083    1 private bath       1.0
# 33  https://www.airbnb.com/rooms/44423    1 private bath       1.0
# 34  https://www.airbnb.com/rooms/47938           2 baths       2.0
# 35  https://www.airbnb.com/rooms/52570               NaN       2.0
# 36  https://www.airbnb.com/rooms/54952     1 shared bath       1.0
# 37  https://www.airbnb.com/rooms/55853            1 bath       1.0
# 38  https://www.airbnb.com/rooms/57049           2 baths       2.0
# 39  https://www.airbnb.com/rooms/57209            1 bath       2.0
#
#     accommodates
# 0              1
# 1              4
# 2              1
# 3              2
# 4              7
# 5              1
# 6              5
# 7              2
# 8              4
# 9              4
# 10             4
# 11             2
# 12             5
# 13             4
# 14             4
# 15             4
# 16             1
# 17             4
# 18             8
# 19             1
# 20             4
# 21             2
# 22             1
# 23             2
# 24             3
# 25             2
# 26             2
# 27             2
# 28             2
# 29             2
# 30             3
# 31             4
# 32             2
# 33             2
# 34             6
# 35             4
# 36             2
# 37             2
# 38             4
# 39             5

# %%
#deal with missing bathrooms (there should be at least 1 bathroom)
listings[listings.bathrooms_text.isna()][['bathrooms_text','listing_url']]
# Out:
#       bathrooms_text                            listing_url
# 35               NaN     https://www.airbnb.com/rooms/52570
# 88               NaN    https://www.airbnb.com/rooms/162111
# 118              NaN    https://www.airbnb.com/rooms/186717
# 123              NaN    https://www.airbnb.com/rooms/189596
# 192              NaN    https://www.airbnb.com/rooms/246007
# 218              NaN    https://www.airbnb.com/rooms/254551
# 271              NaN    https://www.airbnb.com/rooms/302167
# 388              NaN    https://www.airbnb.com/rooms/512476
# 412              NaN    https://www.airbnb.com/rooms/555352
# 416              NaN    https://www.airbnb.com/rooms/563505
# 449              NaN    https://www.airbnb.com/rooms/609459
# 507              NaN    https://www.airbnb.com/rooms/694373
# 698              NaN    https://www.airbnb.com/rooms/958267
# 835              NaN   https://www.airbnb.com/rooms/1230836
# 1034             NaN   https://www.airbnb.com/rooms/1660112
# 1544             NaN   https://www.airbnb.com/rooms/3023254
# 1975             NaN   https://www.airbnb.com/rooms/4066413
# 12320            NaN  https://www.airbnb.com/rooms/28132083
# 18541            NaN  https://www.airbnb.com/rooms/42279207
# 18845            NaN  https://www.airbnb.com/rooms/42687506
# 19560            NaN  https://www.airbnb.com/rooms/43934655
# 19959            NaN  https://www.airbnb.com/rooms/44397450
# 20167            NaN  https://www.airbnb.com/rooms/44654656

# %%
#Assumption: assign 1 bathroom (temporary as string to work with regex strings, cast to floats later on)
listings.loc[listings['bathrooms_text'].isna(), 'bathrooms_text'] = '1'

# %% [raw]
# #assign 1 bathroom to these ones missing
# listings['bathrooms_text'] = np.where(listings['bathrooms_text'].isna(), 1, listings['bathrooms_text'])

# %%
#make sure it worked
listings.bathrooms_text.isna().sum()
# Out:
# 0

# %%
listings['bathrooms_text'].head(20)
# Out:
# 0     1 shared bath
# 1            1 bath
# 2     1 shared bath
# 3     1 shared bath
# 4         2.5 baths
# 5            1 bath
# 6            1 bath
# 7            1 bath
# 8            1 bath
# 9            1 bath
# 10           1 bath
# 11           1 bath
# 12           1 bath
# 13           1 bath
# 14        2.5 baths
# 15        2.5 baths
# 16           1 bath
# 17           1 bath
# 18           1 bath
# 19    1 shared bath
# Name: bathrooms_text, dtype: object

# %%
len(listings['bathrooms_text'])
# Out:
# 20432

# %%
#bathrooms_text is a string and not as useful as a simple float or integer. Extract the numerical values
import re
bath_numbers = []
separator = '.'
for row in listings['bathrooms_text'].values:
    try:
        str(row)
        shards = re.findall(r'[0-9]+', row)
        if len(shards)>1:
            bath_numbers.append(float(separator.join(shards)))
        elif len(shards)==1:
            bath_numbers.append(float(shards[0]))
        elif len(shards)==0:
            bath_numbers.append(0.5)
        else:
            print(shards)
    except Exception as e:
        print(e)

#check lenght again
len(bath_numbers)
# Out:
# 20432

# %%
# tie the numerical values back into the listings
listings['bathrooms_numerical'] = bath_numbers

# %% [markdown]
# ### Join the Wikipedia table (neighborhoods) with the listings (districts)
#
# The listings df already contains the districts. Add the neighborhoods to it!
#
# Wiki Source Page: Table 2 of https://de.wikipedia.org/wiki/Verwaltungsgliederung_Berlins
#
# Plug in address in https://wikitable2csv.ggor.de/ and download CSV to 'Data/AirBNB_Berlin/table-2.csv'

# %%
# the join can be accomplished on the 'district' feature
nbhds = pd.read_csv('Data/AirBNB_Berlin/table-2.csv', header=0, names=['ID', 'neighborhood', 'district', 'area', 'pop', 'pop_density'], encoding="utf-8")
nbhds
# Out:
#       ID        neighborhood       district   area      pop pop_density
# 0    101               Mitte          Mitte  10,70  102.465        9576
# 1    102              Moabit          Mitte   7,72   80.495      10.427
# 2    103        Hansaviertel          Mitte   0,53    5.926      11.181
# 3    104          Tiergarten          Mitte   5,17   14.881        2878
# 4    105             Wedding          Mitte   9,23   86.806        9405
# ..   ...                 ...            ...    ...      ...         ...
# 91  1207       Waidmannslust  Reinickendorf   2,30   10.973        4771
# 92  1208              Lübars  Reinickendorf   5,00    5.203        1041
# 93  1209            Wittenau  Reinickendorf   5,90   24.656        4179
# 94  1210  Märkisches Viertel  Reinickendorf   3,20   40.379      12.618
# 95  1211         Borsigwalde  Reinickendorf   2,00    6.777        3389
#
# [96 rows x 6 columns]

# %% [markdown]
# ### Adjust some district names in the 'listings' for joining

# %%
# see the correct naming from wiki
sorted(nbhds.district.unique())
# Out:
# ['Charlottenburg-Wilmersdorf',
#  'Friedrichshain-Kreuzberg',
#  'Lichtenberg',
#  'Marzahn-Hellersdorf',
#  'Mitte',
#  'Neukölln',
#  'Pankow',
#  'Reinickendorf',
#  'Spandau',
#  'Steglitz-Zehlendorf',
#  'Tempelhof-Schöneberg',
#  'Treptow-Köpenick']

# %%
# listings before
sorted(listings.neighbourhood_group_cleansed.unique())
# Out:
# ['Charlottenburg-Wilm.',
#  'Friedrichshain-Kreuzberg',
#  'Lichtenberg',
#  'Marzahn - Hellersdorf',
#  'Mitte',
#  'Neukölln',
#  'Pankow',
#  'Reinickendorf',
#  'Spandau',
#  'Steglitz - Zehlendorf',
#  'Tempelhof - Schöneberg',
#  'Treptow - Köpenick']

# %%
# rename some neighborhoods - listings after
listings['neighbourhood_group_cleansed'] = np.where(listings['neighbourhood_group_cleansed'] == 'Charlottenburg-Wilm.','Charlottenburg-Wilmersdorf',  listings['neighbourhood_group_cleansed'])
listings['neighbourhood_group_cleansed'] = np.where(listings['neighbourhood_group_cleansed'] == 'Tempelhof - Schöneberg','Tempelhof-Schöneberg',  listings['neighbourhood_group_cleansed'])
listings['neighbourhood_group_cleansed'] = np.where(listings['neighbourhood_group_cleansed'] == 'Steglitz - Zehlendorf','Steglitz-Zehlendorf',  listings['neighbourhood_group_cleansed'])
listings['neighbourhood_group_cleansed'] = np.where(listings['neighbourhood_group_cleansed'] == 'Marzahn - Hellersdorf','Marzahn-Hellersdorf',  listings['neighbourhood_group_cleansed'])
listings['neighbourhood_group_cleansed'] = np.where(listings['neighbourhood_group_cleansed'] == 'Treptow - Köpenick','Treptow-Köpenick',  listings['neighbourhood_group_cleansed'])
sorted(listings.neighbourhood_group_cleansed.unique())
# Out:
# ['Charlottenburg-Wilmersdorf',
#  'Friedrichshain-Kreuzberg',
#  'Lichtenberg',
#  'Marzahn-Hellersdorf',
#  'Mitte',
#  'Neukölln',
#  'Pankow',
#  'Reinickendorf',
#  'Spandau',
#  'Steglitz-Zehlendorf',
#  'Tempelhof-Schöneberg',
#  'Treptow-Köpenick']

# %%
# rename listings column 'neighbourhood_group_cleansed' feature to match nbhd
listings.rename(columns={"neighbourhood_group_cleansed": "district"}, inplace=True)

# %%
#do a join on the districts to add the wikipedia neighbourhoods
#list2 = listings.join(nbhds, on="district")
list2 = pd.merge(listings, nbhds, on='district', how='inner')

# list2 got 5 extra features! (ID, neighborhood, area, pop, pop_density)
list2.shape,listings.shape
# Out:
# ((136034, 78), (20432, 73))

# %% [raw]
# #check to see it worked
# list2 = list2[['neighbourhood','neighbourhood_cleansed']]
# #list2.district2.isna().sum()
# list2

# %% [raw]
# #check new value counts
# list2.district2.value_counts()
# list2.district2.isna().sum()

# %% [raw]
# #check on the shape
# list2.shape,listings.shape

# %% [markdown]
# ### Price feature processing

# %%
#Clean up the price column. 
list2.price.value_counts()
# Out:
# $50.00     6690
# $40.00     5930
# $30.00     5819
# $35.00     5320
# $45.00     4882
#            ...
# $414.00       2
# $47.86        2
# $118.57       2
# $376.57       2
# $542.00       2
# Name: price, Length: 615, dtype: int64

# %%
#strip the $ sign and the thousands-separator comma from the price
list2.price = list2.price.str.replace('$', "")
list2.price = list2.price.str.replace(',', "")
list2.price.value_counts()
# Out:
# 50.00     6690
# 40.00     5930
# 30.00     5819
# 35.00     5320
# 45.00     4882
#           ...
# 63.57        2
# 276.00       2
# 675.00       2
# 558.00       2
# 542.00       2
# Name: price, Length: 615, dtype: int64

# %%
#filter listings to remove price that is listed as 0 or as null
list3 = list2.dropna(subset=['price'], axis=0)
list3.price.isnull().sum()
# Out:
# 0

# %%
#convert to a float
list3['price'] = list3['price'].astype(float)

# funny enough there are some 0 prices?
list3.price.describe()
# Out:
# count    136034.000000
# mean         70.626410
# std         125.542532
# min           0.000000
# 25%          35.000000
# 50%          51.000000
# 75%          80.000000
# max        8000.000000
# Name: price, dtype: float64

# %% [markdown]
# ### B. Join the calendar df (prices) with the listings df (locations)

# %%
calendar
# Out:
#          listing_id        date available   price adjusted_price  \
# 0            186851  2020-09-01         f  $33.00         $33.00
# 1              1944  2020-08-31         f  $20.00         $20.00
# 2              1944  2020-09-01         f  $20.00         $20.00
# 3              1944  2020-09-02         f  $20.00         $20.00
# 4              1944  2020-09-03         f  $20.00         $20.00
# ...             ...         ...       ...     ...            ...
# 7457693    45133552  2021-08-26         f  $26.00         $26.00
# 7457694    45133552  2021-08-27         f  $26.00         $26.00
# 7457695    45133552  2021-08-28         f  $26.00         $26.00
# 7457696    45133552  2021-08-29         f  $26.00         $26.00
# 7457697    45133552  2021-08-30         f  $26.00         $26.00
#
#          minimum_nights  maximum_nights
# 0                  62.0           300.0
# 1                  60.0           120.0
# 2                  60.0           120.0
# 3                  60.0           120.0
# 4                  60.0           120.0
# ...                 ...             ...
# 7457693             3.0            60.0
# 7457694             3.0            60.0
# 7457695             3.0            60.0
# 7457696             3.0            60.0
# 7457697             3.0            60.0
#
# [7457698 rows x 7 columns]

# %%
# the calendar has many entries ranging from present into the future
calendar.shape
# Out:
# (7457698, 7)

# %%
#use only 'adjusted price', drop columns already in the listing df
cal2 = calendar.drop(columns=['price', 'minimum_nights', 'maximum_nights'], axis=0)
cal2.head()
# Out:
#    listing_id        date available adjusted_price
# 0      186851  2020-09-01         f         $33.00
# 1        1944  2020-08-31         f         $20.00
# 2        1944  2020-09-01         f         $20.00
# 3        1944  2020-09-02         f         $20.00
# 4        1944  2020-09-03         f         $20.00

# %% [markdown]
# ### Create a day-of-week column

# %%
cal2.dtypes
# Out:
# listing_id         int64
# date              object
# available         object
# adjusted_price    object
# dtype: object

# %%
#convert date to a datetime object
cal2['date'] = pd.to_datetime(cal2['date'])
cal2.dtypes
# Out:
# listing_id                 int64
# date              datetime64[ns]
# available                 object
# adjusted_price            object
# dtype: object

# %%
#get day of the week 
cal2['day_of_week'] = cal2['date'].dt.day_name()
#get month and year
cal2['month'] = cal2['date'].dt.month
cal2['year'] = cal2['date'].dt.year
#check that it worked
cal2.head()
# Out:
#    listing_id       date available adjusted_price day_of_week  month  year
# 0      186851 2020-09-01         f         $33.00     Tuesday      9  2020
# 1        1944 2020-08-31         f         $20.00      Monday      8  2020
# 2        1944 2020-09-01         f         $20.00     Tuesday      9  2020
# 3        1944 2020-09-02         f         $20.00   Wednesday      9  2020
# 4        1944 2020-09-03         f         $20.00    Thursday      9  2020

# %%
#select only unique rows from: listing_id, adjusted_price, day_of_week, and month
cal3 = cal2.drop_duplicates(subset=['listing_id', 'adjusted_price', 'day_of_week', 'month'], keep=False)
print("Removed duplicates: ",calendar.shape[0] - cal3.shape[0])
# Out:
# Removed duplicates:  7278740

# %%
# how many separate calender entries do some of the listings have?
cal3.listing_id.value_counts()[:10]
# Out:
# 39942268    349
# 30946705    342
# 41785569    336
# 39966304    329
# 35242748    327
# 34356661    323
# 21074683    318
# 22556872    316
# 41099830    316
# 34646721    316
# Name: listing_id, dtype: int64

# %% [markdown]
# ### Adjusted Price

# %%
#strip the $ sign and , from the price
cal3.adjusted_price = cal3.adjusted_price.str.replace('$', "")
cal3.adjusted_price = cal3.adjusted_price.str.replace(',', "")
cal3.adjusted_price = cal3.adjusted_price.astype(float)
cal3.head()
# Out:
# C:\Users\ChristianV700\Anaconda3\lib\site-packages\pandas\core\generic.py:5159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#      listing_id       date available  adjusted_price day_of_week  month  year
# 1          1944 2020-08-31         f            20.0      Monday      8  2020
# 452       64590 2020-08-31         f            98.0      Monday      8  2020
# 572        1944 2020-12-28         t            21.0      Monday     12  2020
# 573        1944 2020-12-29         t            21.0     Tuesday     12  2020
# 574        1944 2020-12-30         t            21.0   Wednesday     12  2020

# %% [markdown]
# ### Finally, join the calendar df (prices) with the listings df (locations)

# %%
#join the cal3 to the list2 on the common ID feature. Tne cal3 columns are now on the right end!
list_cal = list3.join(cal3.set_index('listing_id'), on='id')
list_cal.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  1944  https://www.airbnb.com/rooms/1944  20200830153825   2020-08-31
# 0  1944  https://www.airbnb.com/rooms/1944  20200830153825   2020-08-31
# 0  1944  https://www.airbnb.com/rooms/1944  20200830153825   2020-08-31
# 0  1944  https://www.airbnb.com/rooms/1944  20200830153825   2020-08-31
# 0  1944  https://www.airbnb.com/rooms/1944  20200830153825   2020-08-31
#
#                      name                                        description  \
# 0  cafeheaven Pberg/Mitte  Private, bright and friendly room. You'd be sh...
# 0  cafeheaven Pberg/Mitte  Private, bright and friendly room. You'd be sh...
# 0  cafeheaven Pberg/Mitte  Private, bright and friendly room. You'd be sh...
# 0  cafeheaven Pberg/Mitte  Private, bright and friendly room. You'd be sh...
# 0  cafeheaven Pberg/Mitte  Private, bright and friendly room. You'd be sh...
#
#                                neighborhood_overview  \
# 0  near all the trendy cafés and flea markets and...
# 0  near all the trendy cafés and flea markets and...
# 0  near all the trendy cafés and flea markets and...
# 0  near all the trendy cafés and flea markets and...
# 0  near all the trendy cafés and flea markets and...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/107924758/1f4...     2164
# 0  https://a0.muscache.com/pictures/107924758/1f4...     2164
# 0  https://a0.muscache.com/pictures/107924758/1f4...     2164
# 0  https://a0.muscache.com/pictures/107924758/1f4...     2164
# 0  https://a0.muscache.com/pictures/107924758/1f4...     2164
#
#                                  host_url  ... neighborhood   area      pop  \
# 0  https://www.airbnb.com/users/show/2164  ...        Mitte  10,70  102.465
# 0  https://www.airbnb.com/users/show/2164  ...        Mitte  10,70  102.465
# 0  https://www.airbnb.com/users/show/2164  ...        Mitte  10,70  102.465
# 0  https://www.airbnb.com/users/show/2164  ...        Mitte  10,70  102.465
# 0  https://www.airbnb.com/users/show/2164  ...        Mitte  10,70  102.465
#
#   pop_density       date available adjusted_price day_of_week month    year
# 0        9576 2020-08-31         f           20.0      Monday   8.0  2020.0
# 0        9576 2020-12-28         t           21.0      Monday  12.0  2020.0
# 0        9576 2020-12-29         t           21.0     Tuesday  12.0  2020.0
# 0        9576 2020-12-30         t           21.0   Wednesday  12.0  2020.0
# 0        9576 2020-12-31         t           21.0    Thursday  12.0  2020.0
#
# [5 rows x 84 columns]

# %%
#how many are missing an adjusted price ?
list_cal.adjusted_price.isna().sum()
# Out:
# 79908

# %%
#remove any listings that are missing adjusted price- there is no way to infer
list_cal2 = list_cal.dropna(subset=['adjusted_price'], axis=0)

# %%
#confirm shape meets expectations
list_cal2.shape
# Out:
# (1198065, 84)

# %%
list3.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'district', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms_text',
#        'bedrooms', 'beds', 'amenities', 'price', 'minimum_nights',
#        'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights',
#        'minimum_maximum_nights', 'maximum_maximum_nights',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'bathrooms_numerical', 'ID', 'neighborhood', 'area', 'pop',
#        'pop_density'],
#       dtype='object')

# %% [markdown]
# ## 3. Analyze/Visualize.
#  1. How are prices distributed?
#  2. What is the room type breakdown?
#  3. What is the median price by room type and district?
#  4. Is there a difference in lisiting price by superhost and non superhost?

# %% [markdown]
# #### A. How are the prices distributed?

# %%
plt.figure(figsize=(12,6))
ax = sns.histplot(data=list3, x="price", hue="room_type", fill=True, palette=["#009E73", "#0072B2", "#D55E00","#CC79A7"])
ax.set_title('Price Distribution', fontsize=20)
ax.set_ylabel('Count',fontsize=14)
ax.set_xlabel('Price (USD)',fontsize=14)
ax.tick_params(axis="x", labelsize=14)
ax.tick_params(axis="y", labelsize=14)
plt.xlim(0, 300)
plt.show()

fig = ax.get_figure()
fig.savefig('Data/AirBNB_Berlin/price_distribution.png')

# %% [markdown]
# **Figure summary:**
#
# The price distribution shows that the majority of listings are *Private rooms* and *Entire home/apt*.
#
# The *Private room* category has the majority of its listings cheaper than *Entire home/apt* and also has a shorter tail. The room types *Shared room* and *Hotel room* have much fewer counts.
#
# Listings in the *Shared room* category are cheaper than *Private rooms*. *Hotel room* counts are almost indistinguishible.

# %% [markdown]
# #### B. What is the room type breakdown?

# %%
#generate the input data for the figure. The fig will use automatic raw data to percent conversion.
names = list3.room_type.value_counts().index
size = list3.room_type.value_counts()
names, size
# Out:
# (Index(['Entire home/apt', 'Private room', 'Shared room', 'Hotel room'], dtype='object'),
#  Entire home/apt    76285
#  Private room       56283
#  Shared room         1801
#  Hotel room          1665
#  Name: room_type, dtype: int64)

# %%
plt.figure(figsize=(7,7))

with sns.color_palette(palette=["#0072B2", "#009E73", "#D55E00","#CC79A7"], n_colors=4):
    white_circle = plt.Circle( (0,0), 0.7, color='white')
    patches, texts, autotexts = plt.pie(size, labels=names, autopct='%.0f%%')
    fig = plt.gcf()
    fig.gca().add_artist(white_circle)
    fig.gca().set_title('Room Breakdown', fontsize=20)
    plt.show()
    
fig.savefig('Data/AirBNB_Berlin/room_types.png')

# %% [markdown]
# **Figure summary:**
# The room distribution on AirBnB Berlin is relatively balanced between private rooms (41%) and entire homes/apartments (56%). A much smaller proportion of 1% are shared rooms with other guests, which are hostel style accomodations, and another 1% are listed Hotel rooms.

# %% [markdown]
# #### C. What is the median listing price by room type and district?

# %%
# calculate the ordering of the districts for the graph below
district_price = list3.groupby('district')['price'].median().sort_values(ascending=False)
dist = district_price.index.get_level_values(0)

# actual figure
plt.figure(figsize=(12,6))
ax = sns.pointplot(x="district", y="price", data=list3, order=dist, join=False, estimator=np.median)

#cosmetic stuff
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_xlabel('')
ax.set_ylabel('Price (USD)',fontsize=14)
ax.tick_params(axis="x", labelsize=14)
ax.tick_params(axis="y", labelsize=14)
ax.set_title('Price (Ranges and Median)\n by district', fontsize=20)
ax.set(ylim=(30, 70))
plt.show()

fig.savefig('Data/AirBNB_Berlin/price_range_district.png')

# %% [markdown]
# **Figure Summary:**
#
# All room types combined, the top four most expensive districts are Pankow, Marzahn-Hellersdorf, Mitte, and Charlottenburg-Wilmersdorf. These districts are not necessarily all central tourist districts within Berlin, which is counterintuitive. However, the highest prices of Pankow are explained because on its southern end lies the hot neighborhood "Prenzlauer Berg", which is famous for art, night clubs, etc.  The districts Spandau, Neukölln, Reinickendorf, and Lichtenberg are the least expensive. These least expensive districts are on the outer most perimeter of Berlin and have relatively few tourist destinations.

# %%
with sns.color_palette("husl", 4):
    plt.figure(figsize=(12,6))
    ax = sns.pointplot(x="district", y="price", hue='room_type', data=list3, estimator=np.median, dodge=False, order=dist, join=False, palette=["#009E73", "#0072B2", "#D55E00","#CC79A7", "#F0E442", "#56B4E9"])
    
    #cosmetic stuff
    ax.legend(loc='upper right', fontsize=14)
    ax.set_xlabel('')
    ax.set_ylabel('Price (USD)',fontsize=14)
    ax.tick_params(axis="x", labelsize=14)
    ax.tick_params(axis="y", labelsize=14)
    ax.set_title('Price (Ranges and Median)\n by listing types and district', fontsize=20)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    ax.set(ylim=(0, 150))
    plt.show()

fig = ax.get_figure()
fig.savefig('Data/AirBNB_Berlin/price_range_type_dist.png')

# %% [markdown]
# **Figure summary:**
#
# Generally, listings of the room type category *Hotel* (purple) are most expensive of the four types. The category *Entire homes/apt* (olive) are the most expensive among the non-commercial listings. *Private rooms* (red) are often 25 USD cheaper than Entire homes/apt. *Shared rooms* (green) are least expensive. The Hotel category has in many districts the largest range in prices, which may pull the total median of a district higher.
#
# The median prices of *Private rooms* and *Shared rooms* do not decline in the same pattern as does entire *Home/apartments* but rather, is much more stable among districs. Generally speaking, within a listing category, there is no extreme variablility across districts.

# %% [markdown]
# ### D. What is the difference in price between super host and non super host listings?

# %%
#look at difference in avrage price between superhost and non superhost listings by district and room type (for entire or private)

#remove shared rooms and hotels
list4 = list3[list3['room_type'] != 'Shared room']
list4 = list4[list4['room_type'] != 'Hotel room']

is_superhost = list4[list4['host_is_superhost'] == 't']
is_superhost_grouped = is_superhost.groupby(['room_type', 'district'])['price'].median().reset_index()

not_superhost = list4[list4['host_is_superhost'] == 'f']
not_superhost_grouped = not_superhost.groupby(['room_type', 'district'])['price'].median().reset_index()

# %%
price_by_superhost_status = is_superhost_grouped.rename(columns={'price':"is_superhost_price"})
price_by_superhost_status['not_superhost_price'] = not_superhost_grouped['price']
price_by_superhost_status
# Out:
#           room_type                    district  is_superhost_price  \
# 0   Entire home/apt  Charlottenburg-Wilmersdorf                71.0
# 1   Entire home/apt    Friedrichshain-Kreuzberg                82.0
# 2   Entire home/apt                 Lichtenberg                56.5
# 3   Entire home/apt         Marzahn-Hellersdorf                60.0
# 4   Entire home/apt                       Mitte                90.0
# 5   Entire home/apt                    Neukölln                70.0
# 6   Entire home/apt                      Pankow                77.5
# 7   Entire home/apt               Reinickendorf                60.0
# 8   Entire home/apt                     Spandau               110.5
# 9   Entire home/apt         Steglitz-Zehlendorf                75.0
# 10  Entire home/apt        Tempelhof-Schöneberg                78.0
# 11  Entire home/apt            Treptow-Köpenick                69.0
# 12     Private room  Charlottenburg-Wilmersdorf                35.0
# 13     Private room    Friedrichshain-Kreuzberg                40.0
# 14     Private room                 Lichtenberg                29.0
# 15     Private room         Marzahn-Hellersdorf                31.0
# 16     Private room                       Mitte                40.0
# 17     Private room                    Neukölln                35.0
# 18     Private room                      Pankow                38.0
# 19     Private room               Reinickendorf                34.5
# 20     Private room                     Spandau                31.5
# 21     Private room         Steglitz-Zehlendorf                35.0
# 22     Private room        Tempelhof-Schöneberg                39.0
# 23     Private room            Treptow-Köpenick                34.0
#
#     not_superhost_price
# 0                  69.0
# 1                  70.0
# 2                  54.5
# 3                  72.0
# 4                  75.0
# 5                  60.0
# 6                  72.0
# 7                  50.0
# 8                  47.5
# 9                  65.0
# 10                 63.0
# 11                 60.5
# 12                 39.0
# 13                 36.0
# 14                 30.0
# 15                 30.0
# 16                 35.0
# 17                 31.0
# 18                 38.0
# 19                 30.0
# 20                 35.0
# 21                 34.5
# 22                 35.0
# 23                 30.0

# %%
#calculate difference in median price
price_by_superhost_status['diff'] = price_by_superhost_status['is_superhost_price'] - price_by_superhost_status['not_superhost_price']
price_by_superhost_status
# Out:
#           room_type                    district  is_superhost_price  \
# 0   Entire home/apt  Charlottenburg-Wilmersdorf                71.0
# 1   Entire home/apt    Friedrichshain-Kreuzberg                82.0
# 2   Entire home/apt                 Lichtenberg                56.5
# 3   Entire home/apt         Marzahn-Hellersdorf                60.0
# 4   Entire home/apt                       Mitte                90.0
# 5   Entire home/apt                    Neukölln                70.0
# 6   Entire home/apt                      Pankow                77.5
# 7   Entire home/apt               Reinickendorf                60.0
# 8   Entire home/apt                     Spandau               110.5
# 9   Entire home/apt         Steglitz-Zehlendorf                75.0
# 10  Entire home/apt        Tempelhof-Schöneberg                78.0
# 11  Entire home/apt            Treptow-Köpenick                69.0
# 12     Private room  Charlottenburg-Wilmersdorf                35.0
# 13     Private room    Friedrichshain-Kreuzberg                40.0
# 14     Private room                 Lichtenberg                29.0
# 15     Private room         Marzahn-Hellersdorf                31.0
# 16     Private room                       Mitte                40.0
# 17     Private room                    Neukölln                35.0
# 18     Private room                      Pankow                38.0
# 19     Private room               Reinickendorf                34.5
# 20     Private room                     Spandau                31.5
# 21     Private room         Steglitz-Zehlendorf                35.0
# 22     Private room        Tempelhof-Schöneberg                39.0
# 23     Private room            Treptow-Köpenick                34.0
#
#     not_superhost_price  diff
# 0                  69.0   2.0
# 1                  70.0  12.0
# 2                  54.5   2.0
# 3                  72.0 -12.0
# 4                  75.0  15.0
# 5                  60.0  10.0
# 6                  72.0   5.5
# 7                  50.0  10.0
# 8                  47.5  63.0
# 9                  65.0  10.0
# 10                 63.0  15.0
# 11                 60.5   8.5
# 12                 39.0  -4.0
# 13                 36.0   4.0
# 14                 30.0  -1.0
# 15                 30.0   1.0
# 16                 35.0   5.0
# 17                 31.0   4.0
# 18                 38.0   0.0
# 19                 30.0   4.5
# 20                 35.0  -3.5
# 21                 34.5   0.5
# 22                 35.0   4.0
# 23                 30.0   4.0

# %%
#reorder the dataframe to make it acceptable for barh
price_by_superhost_status.set_index('district')

#Use pivot or unstack:
price_2 = price_by_superhost_status.pivot(index='district',columns='room_type',values='diff')
price_2
# Out:
# room_type                   Entire home/apt  Private room
# district
# Charlottenburg-Wilmersdorf              2.0          -4.0
# Friedrichshain-Kreuzberg               12.0           4.0
# Lichtenberg                             2.0          -1.0
# Marzahn-Hellersdorf                   -12.0           1.0
# Mitte                                  15.0           5.0
# Neukölln                               10.0           4.0
# Pankow                                  5.5           0.0
# Reinickendorf                          10.0           4.5
# Spandau                                63.0          -3.5
# Steglitz-Zehlendorf                    10.0           0.5
# Tempelhof-Schöneberg                   15.0           4.0
# Treptow-Köpenick                        8.5           4.0

# %%
#make grouped bar plot
with sns.color_palette("husl", 3):
    ax = price_2.plot(kind='barh', figsize=(10,10), xlim=(-70,70), stacked=True)
    
    #cosmetic stuff
    ax.set_ylabel('')
    ax.set_xlabel('Price (USD)',fontsize=14)
    ax.tick_params(axis="x", labelsize=14)
    ax.tick_params(axis="y", labelsize=14)
    ax.legend(loc='upper right', fontsize=14)
    ax.annotate('Superhost cheaper\n than non-superhost.', xy=(2,1), size=14, xytext=(-60, 5.2))
    ax.annotate('Superhost more expensive\n than non-superhost.', xy=(2,1), size=14, xytext=(20, 5.2))
    ax.set_title('Median difference Superhost vs Non-Superhost', fontsize=20)
    plt.show
    
plt.savefig('Data/AirBNB_Berlin/Superhost_price_diff.png')

# %% [markdown]
# **Figure summary:**
#
# Colored bars indicate the price difference between superhost and non superhost listings. *Entire homes/apartments* offered by superhosts are more expensive that those offered by non-superhosts in the majority of districts with the exception of Marzahn-Hellersdorf. The largest superhost price premium has to be paid for *Entire home/apt* in Spandau. The price difference is generally larger for *Entire home/apt* than *Private room*, while it is minimized in Pankow, Lichtenberg, and Charlottenburg-Wilmersdorf.
#
# Where are Superhosts chaper?
# - In Spandau, Lichtenberg, and Charlottenburg-Wilmersdorf, a superhost listing for a *Private room* is, on average, less expensive than that offered by a non-superhost.
# - In Marzahn-Hellersdorf, superhost listings for *Entire home/apt* are on average cheaper.
#
# None of these bargain-Superhost districts are located near Berlin's major tourist destinations in Mitte. This means it is probably a valid choice to pick a non-Superhost listing if a cheaper, central location is desired. Counterintuitively, superhosts do not charge a premium everywhere in Berlin. More remote districts are acceptable, then there may be savings possible with superhosts in few, select districts.

# %% [markdown]
# ## 4. Model
# ### E. Which website options influence the price?
#
# In a user mindset -- which factor or option is going to be most influential on the price of listings that are displayed on the website?
#
# ### Features to evaluate:
#  1. minimum nights
#  2. accommodates
#  3. room_type
#  4. beds
#  5. bedrooms
#  6. month
#  7. day_of_week
#  8. host is superhost
#  9. instant bookable
#  10. property type
#  12. district (from wiki)
#  13. has washer
#  14. has dryer
#  15. has Wifi
#  16. has elevator
#  17. bathrooms

# %%
#get the first 20 listing_ids
cal3.listing_id.value_counts()[:5]
# Out:
# 39942268    349
# 30946705    342
# 41785569    336
# 39966304    329
# 35242748    327
# Name: listing_id, dtype: int64

# %%
#confirm adjusted_price of each listing varies
cal3[cal3['listing_id'] == 35242748]['adjusted_price'].value_counts()
# Out:
# 80.0     14
# 83.0      9
# 87.0      9
# 76.0      8
# 84.0      8
#          ..
# 132.0     1
# 139.0     1
# 111.0     1
# 124.0     1
# 127.0     1
# Name: adjusted_price, Length: 116, dtype: int64

# %%
cal3[cal3['listing_id'] == 39966304]['adjusted_price'].value_counts()
# Out:
# 87.0     11
# 82.0      8
# 89.0      8
# 99.0      7
# 88.0      7
#          ..
# 134.0     1
# 159.0     1
# 148.0     1
# 117.0     1
# 66.0      1
# Name: adjusted_price, Length: 125, dtype: int64

# %% [markdown]
# ### The separate amenities we want to check do not have their own features. They are aggregated in the 'Amenities' feature.

# %%
list_cal2.amenities.value_counts()
# Out:
# ["Hangers", "Smoke alarm", "Kitchen", "Hot water", "Laptop-friendly workspace", "Building staff", "Heating", "Long term stays allowed", "Essentials", "Paid parking off premises", "Crib", "Luggage dropoff allowed", "Hair dryer", "Wifi", "TV"]                                                                                                                                                                                                                                                                                                                                         9464
# ["Kitchen", "Free parking on premises", "Heating", "Private entrance", "Essentials", "First aid kit", "Fire extinguisher"]                                                                                                                                                                                                                                                                                                                                                                                                                                                                7185
# ["Kitchen", "Free parking on premises", "Heating", "Private entrance", "First aid kit", "Fire extinguisher"]                                                                                                                                                                                                                                                                                                                                                                                                                                                                              7080
# ["High chair", "Hangers", "Dishes and silverware", "Private entrance", "Washer", "Essentials", "Dryer", "Paid parking on premises", "Baking sheet", "Shampoo", "Smoke alarm", "Cooking basics", "Patio or balcony", "First aid kit", "Paid parking off premises", "Crib", "Fire extinguisher", "Wifi", "Oven", "Iron", "Bed linens", "Hot water", "Extra pillows and blankets", "Heating", "Long term stays allowed", "Single level home", "Stove", "Luggage dropoff allowed", "Shower gel", "Hair dryer", "TV", "Baby bath", "Refrigerator", "Kitchen", "Dishwasher", "Coffee maker"]    6480
# ["Smoke alarm", "Hot water", "Building staff", "Extra pillows and blankets", "Essentials", "First aid kit", "Breakfast", "Luggage dropoff allowed", "Fire extinguisher", "Wifi"]                                                                                                                                                                                                                                                                                                                                                                                                          6230
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# ["Hangers", "Lock on bedroom door", "Smoke alarm", "Kitchen", "Hot water", "Laptop-friendly workspace", "Heating", "Washer", "Essentials", "Free street parking", "Host greets you", "Wifi", "Shampoo"]                                                                                                                                                                                                                                                                                                                                                                                      2
# ["Hangers", "Dishes and silverware", "Washer", "Essentials", "Baking sheet", "Shampoo", "Pocket wifi", "Laptop-friendly workspace", "Cooking basics", "Wifi", "Oven", "Iron", "Bed linens", "Hot water", "Extra pillows and blankets", "Heating", "Stove", "Shower gel", "Hair dryer", "TV", "Refrigerator", "Kitchen", "Coffee maker", "Host greets you", "Elevator"]                                                                                                                                                                                                                       2
# ["Hangers", "Iron", "Smoke alarm", "Kitchen", "Laptop-friendly workspace", "Heating", "Private entrance", "Washer", "Essentials", "First aid kit", "Hair dryer", "Wifi", "Shampoo", "TV"]                                                                                                                                                                                                                                                                                                                                                                                                    2
# ["Kitchen", "Laptop-friendly workspace", "Washer", "Essentials", "Wifi"]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     2
# ["Hangers", "Lock on bedroom door", "Kitchen", "Laptop-friendly workspace", "Heating", "Washer", "Essentials", "Private living room", "Elevator", "Hair dryer", "Wifi"]                                                                                                                                                                                                                                                                                                                                                                                                                      2
# Name: amenities, Length: 7535, dtype: int64

# %%
list_cal2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1198065 entries, 0 to 135997
# Data columns (total 84 columns):
#  #   Column                                        Non-Null Count    Dtype
# ---  ------                                        --------------    -----
#  0   id                                            1198065 non-null  int64
#  1   listing_url                                   1198065 non-null  object
#  2   scrape_id                                     1198065 non-null  int64
#  3   last_scraped                                  1198065 non-null  object
#  4   name                                          1197948 non-null  object
#  5   description                                   1186567 non-null  object
#  6   neighborhood_overview                         846359 non-null   object
#  7   picture_url                                   1198065 non-null  object
#  8   host_id                                       1198065 non-null  int64
#  9   host_url                                      1198065 non-null  object
#  10  host_name                                     1198065 non-null  object
#  11  host_since                                    1198065 non-null  object
#  12  host_location                                 1196840 non-null  object
#  13  host_about                                    673292 non-null   object
#  14  host_response_time                            882089 non-null   object
#  15  host_response_rate                            882089 non-null   object
#  16  host_acceptance_rate                          1009726 non-null  object
#  17  host_is_superhost                             1198065 non-null  object
#  18  host_thumbnail_url                            1198065 non-null  object
#  19  host_picture_url                              1198065 non-null  object
#  20  host_neighbourhood                            931850 non-null   object
#  21  host_listings_count                           1198065 non-null  float64
#  22  host_total_listings_count                     1198065 non-null  float64
#  23  host_verifications                            1198065 non-null  object
#  24  host_has_profile_pic                          1198065 non-null  object
#  25  host_identity_verified                        1198065 non-null  object
#  26  neighbourhood                                 846359 non-null   object
#  27  neighbourhood_cleansed                        1198065 non-null  object
#  28  district                                      1198065 non-null  object
#  29  latitude                                      1198065 non-null  float64
#  30  longitude                                     1198065 non-null  float64
#  31  property_type                                 1198065 non-null  object
#  32  room_type                                     1198065 non-null  object
#  33  accommodates                                  1198065 non-null  int64
#  34  bathrooms_text                                1198065 non-null  object
#  35  bedrooms                                      1198065 non-null  float64
#  36  beds                                          1198065 non-null  float64
#  37  amenities                                     1198065 non-null  object
#  38  price                                         1198065 non-null  float64
#  39  minimum_nights                                1198065 non-null  int64
#  40  maximum_nights                                1198065 non-null  int64
#  41  minimum_minimum_nights                        1198065 non-null  float64
#  42  maximum_minimum_nights                        1198065 non-null  float64
#  43  minimum_maximum_nights                        1198065 non-null  float64
#  44  maximum_maximum_nights                        1198065 non-null  float64
#  45  minimum_nights_avg_ntm                        1198065 non-null  float64
#  46  maximum_nights_avg_ntm                        1198065 non-null  float64
#  47  has_availability                              1198065 non-null  object
#  48  availability_30                               1198065 non-null  int64
#  49  availability_60                               1198065 non-null  int64
#  50  availability_90                               1198065 non-null  int64
#  51  availability_365                              1198065 non-null  int64
#  52  calendar_last_scraped                         1198065 non-null  object
#  53  number_of_reviews                             1198065 non-null  int64
#  54  number_of_reviews_ltm                         1198065 non-null  int64
#  55  number_of_reviews_l30d                        1198065 non-null  int64
#  56  first_review                                  1017285 non-null  object
#  57  last_review                                   1017285 non-null  object
#  58  review_scores_rating                          1006357 non-null  float64
#  59  review_scores_accuracy                        1005883 non-null  float64
#  60  review_scores_cleanliness                     1005883 non-null  float64
#  61  review_scores_checkin                         1005873 non-null  float64
#  62  review_scores_communication                   1005883 non-null  float64
#  63  review_scores_location                        1005873 non-null  float64
#  64  review_scores_value                           1005753 non-null  float64
#  65  license                                       285455 non-null   object
#  66  instant_bookable                              1198065 non-null  object
#  67  calculated_host_listings_count                1198065 non-null  int64
#  68  calculated_host_listings_count_entire_homes   1198065 non-null  int64
#  69  calculated_host_listings_count_private_rooms  1198065 non-null  int64
#  70  calculated_host_listings_count_shared_rooms   1198065 non-null  int64
#  71  reviews_per_month                             1017285 non-null  float64
#  72  bathrooms_numerical                           1198065 non-null  float64
#  73  ID                                            1198065 non-null  int64
#  74  neighborhood                                  1198065 non-null  object
#  75  area                                          1198065 non-null  object
#  76  pop                                           1198065 non-null  float64
#  77  pop_density                                   1198065 non-null  object
#  78  date                                          1198065 non-null  datetime64[ns]
#  79  available                                     1198065 non-null  object
#  80  adjusted_price                                1198065 non-null  float64
#  81  day_of_week                                   1198065 non-null  object
#  82  month                                         1198065 non-null  float64
#  83  year                                          1198065 non-null  float64
# dtypes: datetime64[ns](1), float64(26), int64(18), object(39)
# memory usage: 776.9+ MB

# %%
#make some amenities columns with true/false as flag
list_cal2['has_wifi'] =     np.where(list_cal2['amenities'].str.contains('Wifi', flags=re.IGNORECASE,regex=False),'true', 'false')
list_cal2['has_elevator'] = np.where(list_cal2['amenities'].str.contains('Elevator', flags=re.IGNORECASE,regex=False),'true', 'false')
list_cal2['has_washer'] =   np.where(list_cal2['amenities'].str.contains('Washer', flags=re.IGNORECASE,regex=False),'true', 'false')
list_cal2['has_dryer'] =    np.where(list_cal2['amenities'].str.contains('Dryer', flags=re.IGNORECASE,regex=False),'true', 'false')
list_cal2['has_ac'] =       np.where(list_cal2['amenities'].str.contains('Air conditioning', flags=re.IGNORECASE,regex=False),'true', 'false')
# Out:
# C:\Users\ChristianV700\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ChristianV700\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\ChristianV700\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\ChristianV700\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\ChristianV700\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#trim dataset to explore missing info in only certain columns (removed 'neighbourhood_cleansed'- too many one-hot-categories)
features = list_cal2[['minimum_nights', 'accommodates', 'room_type', 'beds', 'bedrooms', 'month', 'day_of_week', 'host_is_superhost', 'instant_bookable', 'property_type',
                       'district', 'has_washer', 'has_dryer', 'has_wifi', 'has_elevator', 'bathrooms_numerical']]

# %%
#explore the selected data to see about remaining missing information that wasnt taken care of in listings section above
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1198065 entries, 0 to 135997
# Data columns (total 16 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   minimum_nights       1198065 non-null  int64
#  1   accommodates         1198065 non-null  int64
#  2   room_type            1198065 non-null  object
#  3   beds                 1198065 non-null  float64
#  4   bedrooms             1198065 non-null  float64
#  5   month                1198065 non-null  float64
#  6   day_of_week          1198065 non-null  object
#  7   host_is_superhost    1198065 non-null  object
#  8   instant_bookable     1198065 non-null  object
#  9   property_type        1198065 non-null  object
#  10  district             1198065 non-null  object
#  11  has_washer           1198065 non-null  object
#  12  has_dryer            1198065 non-null  object
#  13  has_wifi             1198065 non-null  object
#  14  has_elevator         1198065 non-null  object
#  15  bathrooms_numerical  1198065 non-null  float64
# dtypes: float64(4), int64(2), object(10)
# memory usage: 155.4+ MB

# %%
label = list_cal2['adjusted_price']
label.shape
# Out:
# (1198065,)

# %%
#one-hot-encode categorical data (removed'neighbourhood_cleansed')
features_final = pd.get_dummies(features, columns=['room_type', 'day_of_week', 'host_is_superhost', 'instant_bookable', 'property_type', 'district', 'has_washer', 'has_dryer', 'has_wifi', 'has_elevator'])
features_final.columns
# Out:
# Index(['minimum_nights', 'accommodates', 'beds', 'bedrooms', 'month',
#        'bathrooms_numerical', 'room_type_Entire home/apt',
#        'room_type_Hotel room', 'room_type_Private room',
#        'room_type_Shared room', 'day_of_week_Friday', 'day_of_week_Monday',
#        'day_of_week_Saturday', 'day_of_week_Sunday', 'day_of_week_Thursday',
#        'day_of_week_Tuesday', 'day_of_week_Wednesday', 'host_is_superhost_f',
#        'host_is_superhost_t', 'instant_bookable_f', 'instant_bookable_t',
#        'property_type_Boat', 'property_type_Camper/RV',
#        'property_type_Entire apartment', 'property_type_Entire bungalow',
#        'property_type_Entire cabin', 'property_type_Entire condominium',
#        'property_type_Entire cottage', 'property_type_Entire guest suite',
#        'property_type_Entire guesthouse', 'property_type_Entire house',
#        'property_type_Entire loft', 'property_type_Entire place',
#        'property_type_Entire serviced apartment',
#        'property_type_Entire townhouse', 'property_type_Entire villa',
#        'property_type_Houseboat', 'property_type_Private room',
#        'property_type_Private room in apartment',
#        'property_type_Private room in barn',
#        'property_type_Private room in bed and breakfast',
#        'property_type_Private room in bungalow',
#        'property_type_Private room in camper/rv',
#        'property_type_Private room in cave',
#        'property_type_Private room in condominium',
#        'property_type_Private room in guest suite',
#        'property_type_Private room in guesthouse',
#        'property_type_Private room in hostel',
#        'property_type_Private room in house',
#        'property_type_Private room in loft',
#        'property_type_Private room in pension',
#        'property_type_Private room in serviced apartment',
#        'property_type_Private room in tiny house',
#        'property_type_Private room in tipi',
#        'property_type_Private room in townhouse',
#        'property_type_Private room in villa',
#        'property_type_Room in aparthotel',
#        'property_type_Room in bed and breakfast',
#        'property_type_Room in boutique hotel', 'property_type_Room in hostel',
#        'property_type_Room in hotel',
#        'property_type_Room in serviced apartment',
#        'property_type_Shared room in aparthotel',
#        'property_type_Shared room in apartment',
#        'property_type_Shared room in bed and breakfast',
#        'property_type_Shared room in boutique hotel',
#        'property_type_Shared room in condominium',
#        'property_type_Shared room in hostel',
#        'property_type_Shared room in loft',
#        'property_type_Shared room in tiny house',
#        'property_type_Shared room in townhouse', 'property_type_Tiny house',
#        'district_Charlottenburg-Wilmersdorf',
#        'district_Friedrichshain-Kreuzberg', 'district_Lichtenberg',
#        'district_Marzahn-Hellersdorf', 'district_Mitte', 'district_Neukölln',
#        'district_Pankow', 'district_Reinickendorf', 'district_Spandau',
#        'district_Steglitz-Zehlendorf', 'district_Tempelhof-Schöneberg',
#        'district_Treptow-Köpenick', 'has_washer_false', 'has_washer_true',
#        'has_dryer_false', 'has_dryer_true', 'has_wifi_false', 'has_wifi_true',
#        'has_elevator_false', 'has_elevator_true'],
#       dtype='object')

# %%
# this sklearn function shuffles by default and then splits
X_train, X_test, y_train, y_test = train_test_split(features_final, 
                                                    label, 
                                                    test_size = 0.3, 
                                                    random_state = 42)

# %%
# samples in train vs test
X_train.shape[0], X_test.shape[0]
# Out:
# (838645, 359420)

# %% [markdown]
# ### Use Regressors to Predict Prices
# Methods
#  1. Random Forest
#  2. Linear Regression
#  3. Gradient Boosting

# %% [markdown]
# ### Model 1: Random Forest Regressor

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

#absolute default params
clf = RandomForestRegressor(random_state=42)

# Make predictions using the unoptimized and model
model = clf.fit(X_train, y_train)
randomforest_pred = model.predict(X_test)

# %%
print("Unoptimized model\n------")
print("R2 on testing data: {:.4f}".format(r2_score(y_test, randomforest_pred)))
# Out:
# Unoptimized model
# ------
# R2 on testing data: 0.8820

# %% [markdown]
# It seems that the default options are yielding better results. This model and dataset fed into the model can be worked on to improve prediction accuracy but for now, this is a good starting point.

# %%
#obtain variable importances
importances = model.feature_importances_
importances
# Out:
# array([2.79029863e-02, 1.21990183e-01, 1.52542104e-02, 1.04388185e-02,
#        3.36726004e-01, 4.91401582e-02, 1.17607937e-03, 1.81258490e-02,
#        1.67481032e-03, 2.49845835e-03, 4.65938375e-03, 6.77132138e-03,
#        4.51325065e-03, 2.85503822e-03, 4.24879921e-03, 9.71489162e-03,
#        2.22886288e-03, 8.89961173e-03, 8.77587842e-03, 3.34756478e-03,
#        3.36040463e-03, 6.00046022e-08, 3.07706931e-05, 2.16007292e-02,
#        6.21963370e-05, 2.89241333e-05, 1.02196256e-02, 2.76194124e-05,
#        2.16530768e-05, 8.46534481e-05, 1.28473869e-04, 9.21623864e-04,
#        6.05835312e-06, 3.77222000e-03, 4.57335539e-05, 1.72207228e-05,
#        4.95150757e-03, 4.11778176e-06, 2.59257728e-02, 1.98388977e-08,
#        3.68201635e-06, 5.35900760e-08, 3.76217007e-08, 2.60289534e-07,
#        3.19834619e-05, 1.72901274e-05, 5.23079120e-06, 3.31949903e-04,
#        4.90107992e-04, 6.47276399e-06, 5.40200955e-05, 4.72081903e-05,
#        8.97406086e-07, 3.21676151e-06, 8.51574913e-05, 6.32542935e-06,
#        1.63891465e-04, 4.89797621e-04, 7.98063840e-02, 1.83951158e-03,
#        4.62751949e-02, 4.83856858e-03, 2.46631851e-05, 2.32468200e-05,
#        3.89593792e-08, 1.11916346e-07, 3.84764644e-08, 1.07899522e-03,
#        3.18113351e-08, 1.90107023e-06, 3.33031531e-06, 6.20784815e-05,
#        1.98981952e-02, 2.57576057e-03, 1.34846696e-03, 2.80449411e-04,
#        1.25082248e-02, 1.91823241e-03, 4.21707685e-03, 2.66660799e-04,
#        1.56415683e-04, 7.80437009e-04, 8.57775866e-03, 7.61675479e-03,
#        3.52542462e-03, 4.08706592e-03, 3.48115198e-03, 3.72317159e-03,
#        1.80971167e-03, 1.85516090e-03, 3.79719872e-02, 3.55586695e-02])

# %%
# create new df with imprance values
imp = pd.DataFrame(importances, columns=[ 'importance'])

# add feature columns to a new column named 'features'
imp['feature'] = features_final.columns

# elevate 'features' to index
pd.options.display.float_format = '{:.2f}'.format
imp = imp.set_index('feature')

# %%
#plot variable importance
imp.sort_values('importance', ascending=True).plot(kind='barh', figsize=(15,15))
plt.savefig('Data/AirBNB_Berlin/importance_plot.png')

# %% [markdown]
# **Figure Summary:**
#
# The Random Forest Regressor yielded the most important options driving price variability with a satisfactory model score of R2 = 0.88.
#
# They factors are are in descending importance:
#
# 1. Month
# 2. Number of Persons ('accommodates')
# 3. Boutique Hotel
# 4. Number of Bathrooms
# 5. Hotel Room
# 6. Elevator (presence and absence are equally important)
# 7. Minimum Nights
# 8. Private Room in Apartment
# 9. Entire Apartment
# 10. District "Charlottenburg-Wilmersdorf"
# 11. Hotel
# 12. Beds
# 14. District "Mitte"
#
# The month is twice as important than the numer of people accommodated. As an investigation on the influence of the month I want to visualize the prices per listing type and month.

# %%
month_order = list(range(1,13))

with sns.color_palette("husl", 4):
    plt.figure(figsize=(12,6))
    ax = sns.pointplot(x="month", y="price", hue='room_type', data=list_cal2, estimator=np.median, dodge=False, order=month_order, join=False, palette=["#009E73", "#0072B2", "#D55E00","#CC79A7", "#F0E442", "#56B4E9"])
    
    #cosmetic stuff
    ax.legend(loc='upper right', fontsize=14)
    ax.set_xlabel('')
    ax.set_ylabel('Price (USD)',fontsize=14)
    ax.tick_params(axis="x", labelsize=14)
    ax.tick_params(axis="y", labelsize=14)
    ax.set_title('Price (Ranges and Median)\n by listing types and month', fontsize=20)
    ax.set(ylim=(0, 150))
    plt.show()

fig = ax.get_figure()
fig.savefig('Data/AirBNB_Berlin/price_range_type_month.png')

# %% [markdown]
# **Figure Summary:**
#
# Private room listings jump in prices to almost double in Spring and Summer (March to July). *Entire home/apt* listings also increas during this month, but much less pronounced. *Hotel rooms* have a drop in prices in August, which may or may not be correlated that the data was scraped in August and short-term booking was discounted. *Shared rooms* show very little variance across the year.

# %% [markdown]
# ### Model 2: Linear Regression

# %%
from sklearn.linear_model import LinearRegression

regr = LinearRegression().fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.20181638850109918

# %% [markdown]
# Linear regression has very poor prediction power.

# %% [markdown]
# ### Model 3: Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

clf = GradientBoostingRegressor(random_state=42)
parameters = {'max_features':range(10,60,10)}

#make scorer
scorer = make_scorer(mean_squared_error)

# Perform grid search on the classifier using 'scorer' as the scoring method using GridSearchCV()
grid_obj = GridSearchCV(clf, parameters, scoring=scorer)

# Fit the grid search object to the training data and find the optimal parameters using fit()
grid_fit = grid_obj.fit(X_train, y_train)

# Get the estimator
best_clf = grid_fit.best_estimator_

gb_mod= clf.fit(X_train, y_train)
gb_pred = gb_mod.predict(X_test)
gb_best_pred = best_clf.predict(X_test)

# Report the before-and-afterscores
print("Unoptimized model\n------")
print("R2 on testing data: {:.4f}".format(r2_score(y_test, gb_pred)))
print("\nOptimized Model\n------")
print("Final R2 on the testing data: {:.4f}".format(r2_score(y_test, gb_best_pred)))
# Out:
# Unoptimized model
# ------
# R2 on testing data: 0.4732
#
# Optimized Model
# ------
# Final R2 on the testing data: 0.3260

# %% [markdown]
# **Model Summary:**
#
# The Random Forest Regressor offered the best R2 (0.8820)!

# %% [raw]
# from xgboost.sklearn import XGBClassifier
# from skopt import BayesSearchCV
# from skopt.space import Real, Categorical, Integer
#
# search_space = {"colsample_bylevel": Real(0.6,1),
#                 "colsample_bytree":Real(0.6, 0.8),
#                 "gamma": Real(0.01,5),
#                 "learning_rate": Real(0.0001, 1),
#                 "max_delta_step": Real(0.1, 10),
#                 "max_depth": Integer(3, 15),
#                 "min_child_weight": Real(1, 500),
#                 "n_estimators": Integer(10,200),
#                 "reg_alpha": Real(0.1,100),
#                 "reg_lambda": (0.1, 100),
#                 "subsample": (0.4, 1.0)
#                 }
#
# def on_step(optim_result):
#     """
#     Callback meant to view scores after
#     each iteration while performing Bayesian
#     Optimization in Skopt"""
#     score = XGB_bayes_search.best_score_
#     print("best train score: {}".format(score))
#
# clf = XGBClassifier()
#
# XGB_bayes_search = BayesSearchCV(clf, search_space, n_iter=10, scoring="f1_weighted")
#
# XGB_bayes_search.fit(X_train, y_train, callback=on_step)
#
# # Test classifier
# xgb_pred = XGB_bayes_search.predict(X_test)
#
# # Skopt is optimizing directly
# print("\nOptimized Model\n------")
# print("Final R2 on the testing data: {:.4f}".format(r2_score(y_test, xgb_pred)))
